# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Necessary Libraries Imported

# %% [markdown]
# Import DataFrame

# %%
df = pd.read_csv(r"C:\Users\adwit\Downloads\dataset-eye\dataset-eye.csv")
df
# Out:
#            AF3       F7       F3      FC5       T7        P       O1       O2  \
# 0      4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1      4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2      4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3      4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4      4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14975  4281.03  3990.26  4245.64  4116.92  4333.85  4614.36  4074.87  4625.64
# 14976  4276.92  3991.79  4245.13  4110.77  4332.82  4615.38  4073.33  4621.54
# 14977  4277.44  3990.77  4246.67  4113.85  4333.33  4615.38  4072.82  4623.59
# 14978  4284.62  3991.79  4251.28  4122.05  4334.36  4616.41  4080.51  4628.72
# 14979  4287.69  3997.44  4260.00  4121.03  4333.33  4616.41  4088.72  4638.46
#
# ...

# %% [markdown]
# Use Describe Function to check Mean and other data

# %%
df.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                    P             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# ...

# %% [markdown]
# Use .median and .mode to check Median and Mode for all columns

# %%
df.median()
# Out:
# AF3      4294.36
# F7       4005.64
# F3       4262.56
# FC5      4120.51
# T7       4338.97
# P        4617.95
# O1       4070.26
# O2       4613.33
# P8       4199.49
# T8       4229.23
# FC6      4200.51
# F4       4276.92
# F8       4603.08
# AF4      4354.87
# class       0.00
# dtype: float64

# %%
df.mode()
# Out:
#        AF3       F7       F3      FC5       T7        P       O1       O2  \
# 0  4291.79  4003.59  4263.59  4122.56  4332.31  4616.41  4072.31  4610.77
#
#         P8       T8      FC6       F4       F8      AF4  class
# 0  4196.92  4224.62  4195.38  4273.85  4603.08  4352.31      0

# %% [markdown]
# Check if any data is missing

# %%
df.isnull().sum()
# Out:
# AF3      0
# F7       0
# F3       0
# FC5      0
# T7       0
# P        0
# O1       0
# O2       0
# P8       0
# T8       0
# FC6      0
# F4       0
# F8       0
# AF4      0
# class    0
# dtype: int64

# %% [markdown]
# Checking Skewness for all columns

# %%
plt.figure(figsize = (20,15),facecolor = 'red')
plotnumber = 1
for column in df:
    if plotnumber <= 15:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
    plotnumber +=1
plt.show()

# %% [markdown]
# We can note all columns except target column has skewness due to outliers
#
# z-score or vif can be used to remove this skewness by removing outliers
#
# We need to turn these columns from skewedly normally distributed to normally distributed columns or z-distributed
